# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px

# %%
DJdf = pd.read_csv("C:\\Users\\Andre\\Desktop\\SeniorSpring\\L3Harris-Senior-Capstone\\stock_data\\djia_2012.csv", header=0, names=["Date", "Avg"])

Nasdf = pd.read_csv("C:\\Users\\Andre\\Desktop\\SeniorSpring\\L3Harris-Senior-Capstone\\stock_data\\nasdaq_all.csv")

Russdf = pd.read_csv("C:\\Users\\Andre\\Desktop\\SeniorSpring\\L3Harris-Senior-Capstone\\stock_data\\russel2000_all.csv")

# %%
DJdf["Date"] = pd.to_datetime(DJdf["Date"])

date = DJdf["Date"]
value = DJdf["Avg"]

fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(date, value);

# %%
fig1 = go.Figure(data=go.Ohlc(x=Nasdf['Date'],
                    open=Nasdf['Open'],
                    high=Nasdf['High'],
                    low=Nasdf['Low'],
                    close=Nasdf['Close']))
fig1.show()

# %%
fig = px.line(Nasdf, x='Date', y="Volume")
fig.show()

# %%
fig2 = go.Figure(data=go.Ohlc(x=Russdf['Date'],
                    open=Russdf['Open'],
                    high=Russdf['High'],
                    low=Russdf['Low'],
                    close=Russdf['Close']))
fig2.show()

# %%
fig = px.line(Russdf, x='Date', y="Volume")
fig.show()
